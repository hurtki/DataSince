# %%
# all the excersises from 1.3 python targilim file

def conkatination(list1, list2) -> list:
  return list1 + list2


def handle_odd_even_list(num_list: list):
  odd_list = []
  even_list = []
  for num in num_list:
    if num % 2 == 0:
      even_list.append(num)
    else:
      odd_list.append(num)
  print(odd_list, even_list)

def efresh_bein_lists(list1, list2):
  for i in list1:
    if not i in list2:
      print(i)

def only_even_indexes(list: list) -> list:
  return [list[i] for i in range(0,len(list), 2)]

def oboyudnaya_summa(list1, list2) -> list:
  return [(list1[i] + list2[i]) for i in range(len(list1))]

# %%
from typing import Concatenate

def maxl(array):
  max = -9999
  for i in array:
    if max < i:
      max = i
  return max


def minl(array):
  min = 9999
  for i in array:
    if min > i:
      min = i
  return min

def max_min_memuza(list1, list2, list3):
  return_list = [maxl(list1), minl(list2), sum(list3) / len(list3)]
  return return_list

def max_of_the_lists(list1, list2):
  if len(list1) > len(list2):
    return list1[::-1]
  else:
    return list2[::-1]

def all_divided_by_2_or_3_before_num(num: int) -> list[int]:
  return [i for i in range(1, num + 1) if i % 2 == 0 or i % 3 == 0]

def all_that_are_greater_than_num_from_list(array: list, num: int) -> list:
  return [i for i in array if i > num]

def conkatination(list1, list2) -> list:
  return list1 + list2


def concat_with_reversed_list(array: list) -> list:
  return conkatination(array, array[::-1])
# Out:
# [6, 7, 8, 9, 10]

# %% [markdown]
# ## Dict data structure

# %% [markdown]
# Is a structure of the type key-value

# %%
# Out:
# 'test2'
